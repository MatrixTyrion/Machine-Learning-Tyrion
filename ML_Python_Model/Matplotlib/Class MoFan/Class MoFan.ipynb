# %% [markdown]
# # 基本用法

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-1, 1, 50)
y = 2 * x + 1

# %%
plt.plot(x, y)
plt.show()

# %%
y = x ** 2
plt.plot(x, y)

# %% [markdown]
# # figure 图像

# %%
x = np.linspace(-1, 1, 50)
y1 = 2 * x + 1
y2 = x ** 2

# %%
plt.figure()
plt.plot(x, y1)

plt.figure()
plt.plot(x, y2)

plt.show()

# %%
plt.figure(num=3, figsize=(8,5))
plt.plot(x, y2)

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)

# %% [markdown]
# # 设置坐标轴

# %%
x = np.linspace(-1, 1, 50)
y1 = 2 * x + 1
y2 = x ** 2

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)

# 设置坐标轴 - 取值范围
plt.xlim((-1,2))
plt.ylim((-2,3))
# Out:
# (-2, 3)

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)

# 设置坐标轴 - 取值范围
plt.xlim((-1,2))
plt.ylim((-2,3))

# 设置坐标轴 - 描述
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0,0.5,'Y')

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)

plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)
# 设置坐标轴 - 取值范围
plt.xlim((-1,2))
plt.ylim((-2,3))

# 设置坐标轴 - 描述
plt.xlabel("X")
plt.ylabel("Y")
new_ticks = np.linspace(-1, 2, 5)
print('new_ticks', new_ticks)

plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3], [r'$really\ bad$', r'$bad$', r'$normal\ \alpha$', r'$good$', r'$really\ good$'])
# Out:
# new_ticks [-1.   -0.25  0.5   1.25  2.  ]
# ([<matplotlib.axis.YTick at 0x23656bcb6d8>,
#   <matplotlib.axis.YTick at 0x23656b9af98>,
#   <matplotlib.axis.YTick at 0x23656b8a320>,
#   <matplotlib.axis.YTick at 0x23656a7b240>,
#   <matplotlib.axis.YTick at 0x23656a7bba8>],
#  <a list of 5 Text yticklabel objects>)

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)

plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)
# 设置坐标轴 - 取值范围
plt.xlim((-1,2))
plt.ylim((-2,3))

# 设置坐标轴 - 描述
plt.xlabel("X")
plt.ylabel("Y")
new_ticks = np.linspace(-1, 2, 5)
print('new_ticks', new_ticks)

plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3], [r'$really\ bad$', r'$bad$', r'$normal\ \alpha$', r'$good$', r'$really\ good$'])

# 修改坐标轴位置
# gca = "get current axis"
ax = plt.gca()
ax.spines['right'].set_color('none') # 脊梁
ax.spines['top'].set_color('none')
# Out:
# new_ticks [-1.   -0.25  0.5   1.25  2.  ]

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)

plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)
# 设置坐标轴 - 取值范围
plt.xlim((-1,2))
plt.ylim((-2,3))

# 设置坐标轴 - 描述
plt.xlabel("X")
plt.ylabel("Y")
new_ticks = np.linspace(-1, 2, 5)
print('new_ticks', new_ticks)

plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3], [r'$really\ bad$', r'$bad$', r'$normal\ \alpha$', r'$good$', r'$really\ good$'])

# 修改坐标轴位置
# gca = "get current axis"
ax = plt.gca()
ax.spines['right'].set_color('none') # 脊梁
ax.spines['top'].set_color('none')

# 设置代替坐标轴
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# 挪动坐标轴
ax.spines['bottom'].set_position(('data', -1)) # 设置横轴在纵坐标为 '-1' 的位置
ax.spines['left'].set_position(('data', 0.5))
# Out:
# new_ticks [-1.   -0.25  0.5   1.25  2.  ]

# %% [markdown]
# # legend 图例

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)


# 设置坐标轴 - 取值范围
plt.xlim((-1,2))
plt.ylim((-2,3))

# 设置坐标轴 - 描述
plt.xlabel("X")
plt.ylabel("Y")
new_ticks = np.linspace(-1, 2, 5)
print('new_ticks', new_ticks)

plt.xticks(new_ticks)
plt.yticks([-2, -1.8, -1, 1.22, 3], [r'$really\ bad$', r'$bad$', r'$normal\ \alpha$', r'$good$', r'$really\ good$'])

plt.figure()
plt.plot(x, y1, label='up', color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2, label='down')

# 打印图例
plt.legend()
# Out:
# new_ticks [-1.   -0.25  0.5   1.25  2.  ]

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)


# 设置坐标轴 - 描述
plt.xlabel("X")
plt.ylabel("Y")

plt.figure(figsize=(8,5))
line1, = plt.plot(x, y1, label='up', color='red', linewidth=2.0, linestyle='--')
line2, = plt.plot(x, y2, label='down')

# 打印图例 - 替换图例 label
plt.legend(handles=[line1, line2], labels=['jean', 'tyrion'], loc='best')

# %%
plt.figure()
plt.plot(x, y1, color='red', linewidth=2.0, linestyle='--')
plt.plot(x, y2)


# 设置坐标轴 - 描述
plt.xlabel("X")
plt.ylabel("Y")

plt.figure(figsize=(8,5))
line1, = plt.plot(x, y1, label='up', color='red', linewidth=2.0, linestyle='--')
line2, = plt.plot(x, y2, label='down')

# 打印图例 - 替换图例 label
plt.legend(handles=[line1, ], labels=['jean', ], loc='best')

# %% [markdown]
# # annotation 注释

# %%
def ori():
    x = np.linspace(-3, 3, 50)
    y = 2*x + 1

    plt.figure(num=1, figsize=(8, 5),)
    plt.plot(x, y,)

    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.spines['bottom'].set_position(('data', 0))
    ax.yaxis.set_ticks_position('left')
    ax.spines['left'].set_position(('data', 0))

ori()

# %%
ori()

# 添加点
x0 = 1
y0 = 2 * x0 + 1
plt.scatter(x0, y0, s=50, color='r')

# %%
ori()

# 添加点
x0 = 1
y0 = 2 * x0 + 1
plt.scatter(x0, y0, s=50, color='r')

# 添加直线
plt.plot([x0, x0], [y0, 0], 'k--', lw=2.5)

# %%
ori()

# 添加点
x0 = 1
y0 = 2 * x0 + 1
plt.scatter(x0, y0, s=50, color='r')

# 添加直线
plt.plot([x0, x0], [y0, 0], 'k--', lw=2.5)

# 添加注释
# method 1
plt.annotate(r'$2x+1=%s$' %y0, xy=(x0, y0))
# Out:
# Text(1,3,'$2x+1=3$')

# %%
ori()

# 添加点
x0 = 1
y0 = 2 * x0 + 1
plt.scatter(x0, y0, s=50, color='r')

# 添加直线
plt.plot([x0, x0], [y0, 0], 'k--', lw=2.5)

# 添加注释
# method 1
plt.annotate(r'$2x+1=%s$' %y0, xy=(x0, y0),
             xycoords='data',
             xytext=(+30, -30),
             textcoords='offset points'
            )
# Out:
# Text(30,-30,'$2x+1=3$')

# %%
ori()

# 添加点
x0 = 1
y0 = 2 * x0 + 1
plt.scatter(x0, y0, s=50, color='r')

# 添加直线
plt.plot([x0, x0], [y0, 0], 'k--', lw=2.5)

# 添加注释
# method 1
plt.annotate(r'$2x+1=%s$' %y0, xy=(x0, y0),
             xycoords='data',
             xytext=(+30, -30),
             textcoords='offset points',
             fontsize=16,
             arrowprops=dict(arrowstyle='->', connectionstyle="arc3,rad=.2")
            )
# Out:
# Text(30,-30,'$2x+1=3$')

# %%
ori()

# 添加点
x0 = 1
y0 = 2 * x0 + 1
plt.scatter(x0, y0, s=50, color='r')

# 添加直线
plt.plot([x0, x0], [y0, 0], 'k--', lw=2.5)

# 添加注释
# method 2 : 添加纯文本
plt.text(-3.7, 3, 
         r'$This\ is\ the\ some\ text. \mu\ \sigma_i\ \alpha_t$',
         fontdict={'size': 16, 'color': 'r'}
        )
# Out:
# Text(-3.7,3,'$This\\ is\\ the\\ some\\ text. \\mu\\ \\sigma_i\\ \\alpha_t$')

# %% [markdown]
# # tick 能见度

# %%
x = np.linspace(-3, 3, 50)
y = 0.1*x

plt.figure()
# 在 plt 2.0.2 或更高的版本中, 设置 zorder 给 plot 在 z 轴方向排序
plt.plot(x, y, linewidth=10, zorder=1)
plt.ylim(-2, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

# %%
x = np.linspace(-3, 3, 50)
y = 0.1*x

plt.figure()
# 在 plt 2.0.2 或更高的版本中, 设置 zorder 给 plot 在 z 轴方向排序
plt.plot(x, y, linewidth=10, zorder=1)
plt.ylim(-2, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)
    # 在 plt 2.0.2 或更高的版本中, 设置 zorder 给 plot 在 z 轴方向排序
    # alpha : 不透明度
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.3, zorder=2))
plt.show()

# %% [markdown]
# # Scatter 散点图

# %%
n = 1024    # data size
X = np.random.normal(0, 1, n) # 每一个点的X值
Y = np.random.normal(0, 1, n) # 每一个点的Y值
T = np.arctan2(Y,X) # for color value

# %%
plt.scatter(X, Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5, 1.5)
plt.xticks(())  # ignore xticks
plt.ylim(-1.5, 1.5)
plt.yticks(())  # ignore yticks

plt.show()

# %% [markdown]
# # Bar 柱状图

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.bar(X, +Y1)
plt.bar(X, -Y2)

plt.xlim(-.5, n)
plt.xticks(())
plt.ylim(-1.25, 1.25)
plt.yticks(())

plt.show()

# %%
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
# Out:
# <BarContainer object of 12 artists>

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.bar(X, +Y1)
plt.bar(X, -Y2)

plt.xlim(-.5, n)
plt.xticks(())
plt.ylim(-1.25, 1.25)
plt.yticks(())

for x, y in zip(X, Y1):
    # ha: horizontal alignment
    # va: vertical alignment
    plt.text(x, y + 0.05, '%.2f' % y, ha='center', va='bottom')

for x, y in zip(X, Y2):
    # ha: horizontal alignment
    # va: vertical alignment
    plt.text(x, -y - 0.05, '%.2f' % y, ha='center', va='top')

    
plt.show()

# %% [markdown]
# # Contours 等高线图

# %%
def f(x,y):
    # the height function
    return (1 - x / 2 + x**5 + y**3) * np.exp(-x**2 -y**2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X,Y = np.meshgrid(x, y)

# %%
# use plt.contourf to filling contours
# X, Y and value for (X,Y) point
plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap=plt.cm.hot)

# %%
# use plt.contourf to filling contours
# X, Y and value for (X,Y) point
plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap=plt.cm.hot)

# use plt.contour to add contour lines
C = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidths=.5)

# %%
# use plt.contourf to filling contours
# X, Y and value for (X,Y) point
plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap=plt.cm.hot)

# use plt.contour to add contour lines
C = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidths=.5)

plt.clabel(C, inline=True, fontsize=10)
plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# # Image 图片

# %%
a = np.array([0.313660827978, 0.365348418405, 0.423733120134,
              0.365348418405, 0.439599930621, 0.525083754405,
              0.423733120134, 0.525083754405, 0.651536351379]).reshape(3,3)
plt.imshow(a, interpolation='nearest', cmap='bone', origin='lower')

plt.xticks(())
plt.yticks(())
plt.show()

# %%
a = np.array([0.313660827978, 0.365348418405, 0.423733120134,
              0.365348418405, 0.439599930621, 0.525083754405,
              0.423733120134, 0.525083754405, 0.651536351379]).reshape(3,3)
plt.imshow(a, interpolation='bessel', cmap='bone', origin='upper')

plt.xticks(())
plt.yticks(())
plt.show()

# %%
a = np.array([0.313660827978, 0.365348418405, 0.423733120134,
              0.365348418405, 0.439599930621, 0.525083754405,
              0.423733120134, 0.525083754405, 0.651536351379]).reshape(3,3)
plt.imshow(a, interpolation='nearest', cmap='bone', origin='lower')

plt.colorbar(shrink=.92)

plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# # 3-Dim 数据

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)

# %%
fig = plt.figure()
ax = Axes3D(fig)

# X, Y value
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)    # x-y 平面的网格
R = np.sqrt(X ** 2 + Y ** 2)
# height value
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))

# %%
fig = plt.figure()
ax = Axes3D(fig)

# X, Y value
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)    # x-y 平面的网格
R = np.sqrt(X ** 2 + Y ** 2)
# height value
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))

ax.contourf(X, Y, Z, zdir='z', offset=-3, cmap=plt.get_cmap('rainbow'))
ax.set_zlim(-2,2)
# Out:
# (-2, 2)

# %% [markdown]
# # Subplot 多合一显示

# %%
plt.figure()

plt.subplot(2,2,1)
plt.plot([0,1],[0,1])

plt.subplot(2,2,2)
plt.plot([0,1],[0,2])

plt.subplot(223)
plt.plot([0,1],[0,3])

plt.subplot(224)
plt.plot([0,1],[0,4])

plt.show()  # 展示

# %%
plt.subplot(2,1,1)
plt.plot([0,1],[0,1])

plt.subplot(2,3,4)
plt.plot([0,1],[0,2])

plt.subplot(235)
plt.plot([0,1],[0,3])

plt.subplot(236)
plt.plot([0,1],[0,4])

plt.show()  # 展示

# %% [markdown]
# # Subplot 分格显示

# %%
plt.figure(figsize=(10,10))

ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
ax1.plot([1, 2], [1, 2])    # 画小图
ax1.set_title('ax1_title')  # 设置小图的标题

ax2 = plt.subplot2grid((3, 3), (1, 0), colspan=2)
ax3 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)
ax4 = plt.subplot2grid((3, 3), (2, 0))
ax5 = plt.subplot2grid((3, 3), (2, 1))

ax4.scatter([1, 2], [2, 20])
ax4.set_xlabel('ax4_x')
ax4.set_ylabel('ax4_y')
# Out:
# Text(0,0.5,'ax4_y')

# %%
import matplotlib.gridspec as gridspec

# %%
plt.figure(figsize=(10,10))
gs = gridspec.GridSpec(3, 3)

ax6 = plt.subplot(gs[0, :])
ax7 = plt.subplot(gs[1, :2])
ax8 = plt.subplot(gs[1:, 2])
ax9 = plt.subplot(gs[-1, 0])
ax10 = plt.subplot(gs[-1, -2])
ax10.plot([1,-1,120], [2,31,12])

# %%
f, ((ax11, ax12), (ax13, ax14)) = plt.subplots(2, 2, sharex=True, sharey=True)
ax11.scatter([1,2], [1,2])
plt.tight_layout()
plt.show()

# %% [markdown]
# # 图中图

# %%
# 初始化figure
fig = plt.figure()

# 创建数据
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 3, 4, 2, 5, 8, 6]

left, bottom, width, height = 0.1, 0.1, 0.8, 0.8

ax1 = fig.add_axes([left, bottom, width, height])
ax1.plot(x, y, 'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title')
# Out:
# Text(0.5,1,'title')

# %%
# 初始化figure
fig = plt.figure()

# 创建数据
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 3, 4, 2, 5, 8, 6]

left, bottom, width, height = 0.1, 0.1, 0.8, 0.8

ax1 = fig.add_axes([left, bottom, width, height])
ax1.plot(x, y, 'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title')

left, bottom, width, height = 0.2, 0.6, 0.25, 0.25
ax2 = fig.add_axes([left, bottom, width, height])
ax2.plot(y, x, 'b')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('title inside 1')
# Out:
# Text(0.5,1,'title inside 1')

# %%
# 初始化figure
fig = plt.figure()

# 创建数据
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 3, 4, 2, 5, 8, 6]

left, bottom, width, height = 0.1, 0.1, 0.8, 0.8

ax1 = fig.add_axes([left, bottom, width, height])
ax1.plot(x, y, 'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title')

left, bottom, width, height = 0.2, 0.6, 0.25, 0.25
ax2 = fig.add_axes([left, bottom, width, height])
ax2.plot(y, x, 'b')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('title inside 1')
# Out:
# Text(0.5,1,'title inside 1')

# %%
# 初始化figure
fig = plt.figure()

# 创建数据
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 3, 4, 2, 5, 8, 6]

left, bottom, width, height = 0.1, 0.1, 0.8, 0.8

ax1 = fig.add_axes([left, bottom, width, height])
ax1.plot(x, y, 'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title')

plt.axes([0.6, 0.2, 0.25, 0.25])
plt.plot(y[::-1], x, 'g') # 注意对y进行了逆序处理
plt.xlabel('x')
plt.ylabel('y')
plt.title('title inside 2')
# Out:
# Text(0.5,1,'title inside 2')

# %% [markdown]
# # 次坐标

# %%
x = np.arange(0, 10, 0.1)
y1 = 0.05 * x**2
y2 = 1 * x

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(x, y1, 'g-')   # green, solid line
ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')
# Out:
# Text(0,0.5,'Y1 data')

# %%
x = np.arange(0, 10, 0.1)
y1 = 0.05 * x**2
y2 = 1 * x

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(x, y1, 'g-')   # green, solid line
ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')

ax2.plot(x, y2, 'b-') # blue
ax2.set_ylabel('Y2 data', color='b')
# Out:
# Text(0,0.5,'Y2 data')

# %% [markdown]
# # Animation 动画

# %%
from matplotlib import animation

# %%
fig, ax = plt.subplots()
x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))

# %%
def animate(i):
    line.set_ydata(np.sin(x + i/10.0))
    return line,

def init():
    line.set_ydata(np.sin(x))
    return line,

ani = animation.FuncAnimation(fig=fig,
                              func=animate,
                              frames=100,
                              init_func=init,
                              interval=20,
                              blit=True)
plt.show()

# %%
ani.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])
